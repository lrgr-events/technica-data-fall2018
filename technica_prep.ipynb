# %%
import pandas as pd
import numpy as np
import scipy as sp
from collections import Counter
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load datasets

# %%
df_RPKM = pd.read_csv('CCLE_RNAseq_RPKM.gct',sep = '\t', header=0, skiprows = range(0,2)) 
#skip rows first then set header, so header = 0
df_GR = pd.read_csv('gcsi_drug_response.csv')

# %%
df_mut = pd.read_csv('CCLE_mutation_data.txt',sep = '\t',low_memory = False)

# %% [markdown]
# ### Broad ID of cell lines and the corresponding number of genes with mutation status

# %%
ID = list(df_mut['Broad_ID'])
counts = dict(Counter(ID))
df_mc = pd.DataFrame(counts,index = [0]).T
df_mc= df_mc.reset_index(inplace=False)
df_mc.columns = ['Broad ID','Number of genes with mut status recorded for this cell line']
df_mc = df_mc.sort_values(by = ['Broad ID'],ascending= True) 
#Broad ID of cell lines and the corresponding number of genes with mut status"
#df_mc.to_csv('Cell lines and corresponding number of genes with variant classification.csv',sep=',')

# %%
df_mc[0:20]
# Out:
#       Broad ID  Number of genes with mut status recorded for this cell line
# 0   ACH-000001                                                303
# 1   ACH-000002                                                195
# 2   ACH-000003                                                225
# 3   ACH-000004                                                296
# 4   ACH-000005                                                315
# 5   ACH-000006                                                220
# 6   ACH-000007                                                535
# 7   ACH-000008                                                363
# 8   ACH-000009                                                439
# 9   ACH-000010                                                201
# 10  ACH-000011                                                403
# 11  ACH-000012                                                283
# 12  ACH-000013                                                269
# 13  ACH-000014                                                793
# 14  ACH-000015                                                376
# 15  ACH-000016                                                172
# 16  ACH-000017                                                289
# 17  ACH-000018                                                266
# 18  ACH-000019                                                654
# 19  ACH-000020                                                102

# %% [markdown]
# It is pretty obvious that the cell lines don't have mutations status for all the genes, and different cell lines have differet number of genes with recorded mutation status.

# %% [markdown]
# ### Generate dict of cell name and corresponding broad ID in RNAseq expression data

# %%
rpkm_cells = list(df_RPKM.columns)
rpkm_cells.remove('Name')
rpkm_cells.remove('Description')

# %%
cell_ID = dict()
for item in rpkm_cells:
    pair = item.split(' (')
    value = pair[0].split('_')[0]
    key = pair[1][:-1]
    cell_ID[key]=value
#dict of cell name and corresponding broad ID

# %% [markdown]
# ### Intersection of all three datasets

# %%
GR_cell = set(list(df_GR['Cell_Line']))
RPKM_cell = set(cell_ID.values())

# %%
cell_GR_RPKM = GR_cell.intersection(RPKM_cell)

# %%
#convert broad ID to cell line name for cell lines with variant classification
VC_cell = []
VC_cell_broad = set(df_mc['Broad ID'])
VC_cell_int = VC_cell_broad.intersection(set(cell_ID.keys()))
for item in VC_cell_int:
    VC_cell.append(cell_ID[item])
VC_cell = set(VC_cell)

# %%
cell_GR_RPKM_VC = VC_cell.intersection(cell_GR_RPKM)

# %%
len(cell_GR_RPKM_VC)
# Out:
# 355

# %%
#cell_GR_RPKM_VC

# %% [markdown]
# The total number of cell lines found in all three dataset is 355.

# %% [markdown]
# ### Processing of the gcsi dataset

# %%
df_GR_truncated = pd.concat([df_GR['Cell_Line'],df_GR['Perturbagen'],df_GR['GRinf'],df_GR['GR_AOC'],df_GR['Tissue']],axis =1)
df = pd.DataFrame()
for item in cell_GR_RPKM_VC:
    df=df.append(df_GR_truncated[df_GR_truncated['Cell_Line']==item])
df.reset_index(inplace=True,drop=True)

# %%
response = []
for index, row in df.iterrows():
    if row['GR_AOC']>0.5 and row['GRinf'] <0:
        response.append('Yes')
    else:
        response.append('No')
df['Response']=response

# %%
df[0:20]
# Out:
#    Cell_Line   Perturbagen     GRinf    GR_AOC   Tissue Response
# 0       U2OS       bid1870  0.858640  0.046695     Bone       No
# 1       U2OS    bortezomib -0.837610  0.554880     Bone      Yes
# 2       U2OS    crizotinib  0.431040 -0.001386     Bone       No
# 3       U2OS     docetaxel  0.089875  0.355130     Bone       No
# 4       U2OS   doxorubicin -0.370880  0.467940     Bone       No
# 5       U2OS     erlotinib  0.647660  0.113870     Bone       No
# 6       U2OS       gdc0941  0.666650  0.204310     Bone       No
# 7       U2OS   gemcitabine  0.714210  0.134600     Bone       No
# 8       U2OS    irinotecan -0.965770  0.087327     Bone       No
# 9       U2OS     lapatinib -1.000000  0.203810     Bone       No
# 10      U2OS         ms275  0.967800  0.009422     Bone       No
# 11      U2OS    paclitaxel  0.085468  0.396760     Bone       No
# 12      U2OS     pd0325901 -0.187490  0.467830     Bone       No
# 13      U2OS     rapamycin  0.490260  0.285720     Bone       No
# 14      U2OS  thapsigargin -0.559960  0.378630     Bone       No
# 15      U2OS    vorinostat -0.635520  0.341820     Bone       No
# 16     8505C       bid1870 -0.617570  0.077601  Thyroid       No
# 17     8505C    bortezomib -0.584630  0.622190  Thyroid      Yes
# 18     8505C    crizotinib  0.694190 -0.013967  Thyroid       No
# 19     8505C     docetaxel -0.029018  0.366380  Thyroid       No

# %%
df.to_csv('drug_response_processed.csv',sep =',')

# %%
tissue = list(df.Tissue)

# %%
graoc = df.set_index('Cell_Line')['GR_AOC'].to_dict()

# %%
len(graoc)
# Out:
# 355

# %%
tissue_counts= pd.DataFrame(dict(Counter(tissue)),index = [0]).T
tissue_counts= tissue_counts.reset_index(inplace=False)
tissue_counts.columns = ['Tissue','counts']
tissue_counts= tissue_counts.sort_values(by=['counts'],ascending=False)

# %%
tissue_counts.counts =tissue_counts.counts/16

# %%
tissue_counts.counts.sum()
# Out:
# 350.25

# %%
# Out:
#            Tissue   counts
# 7            Lung  59.5625
# 5           Blood  29.0000
# 11         Breast  28.3125
# 6            Skin  27.9375
# 3        Pancreas  27.0000
# 2           Brain  24.9375
# 8           Ovary  24.0000
# 12          Colon  21.9375
# 9           Liver  17.5000
# 4         Stomach  16.3125
# 13      Esophagus  14.0000
# 10         Uterus  12.0000
# 15         Kidney  10.0000
# 19       Lymphoid   9.7500
# 0            Bone   4.6875
# 17            NaN   4.3125
# 14        Urinary   4.0000
# 18  Head and Neck   4.0000
# 1         Thyroid   4.0000
# 16       Prostate   3.0000
# 20         Cervix   3.0000
# 21         Muscle   1.0000

# %%
tissue_dict = df.set_index('Cell_Line')['Tissue'].to_dict()

# %%
tissue_dict
# Out:
# {'2313287': 'Stomach',
#  '769P': 'Kidney',
#  '786O': 'Kidney',
#  '8305C': 'Thyroid',
#  '8505C': 'Thyroid',
#  'A172': 'Brain',
#  'A2058': 'Skin',
#  'A2780': 'Ovary',
#  'A375': 'Skin',
#  'A498': 'Kidney',
#  'A549': 'Lung',
#  'A673': 'Muscle',
#  'ABC1': 'Lung',
#  'ACHN': 'Kidney',
#  'AGS': 'Stomach',
#  'AMO1': 'Blood',
#  'AN3CA': 'Uterus',
#  'ASPC1': 'Pancreas',
#  'AU565': 'Breast',
#  'BCPAP': 'Thyroid',
#  'BEN': 'Lung',
#  'BFTC909': 'Kidney',
#  'BHY': 'Head and Neck',
#  'BT20': 'Breast',
#  'BT474': 'Breast',
#  'BT549': 'Breast',
#  'BXPC3': 'Pancreas',
#  'C2BBE1': 'Colon',
#  'C32': 'Skin',
#  'C33A': 'Cervix',
#  'CA46': 'Blood',
#  'CAKI1': 'Kidney',
#  'CAKI2': 'Kidney',
#  'CAL120': 'Breast',
#  'CAL12T': 'Lung',
#  'CAL148': 'Breast',
#  'CAL27': 'Head and Neck',
#  'CAL51': 'Breast',
#  'CAL54': 'Kidney',
#  'CALU3': 'Lung',
#  'CAMA1': 'Breast',
#  'CAPAN1': 'Pancreas',
#  'CAPAN2': 'Pancreas',
#  'CASKI': 'Cervix',
#  'CCFSTTG1': 'Brain',
#  'CFPAC1': 'Pancreas',
#  'CHAGOK1': 'Lung',
#  'CHP212': 'Brain',
#  'CI1': 'Lymphoid',
#  'COLO201': 'Colon',
#  'COLO678': 'Colon',
#  'COLO679': 'Skin',
#  'COLO680N': 'Esophagus',
#  'COLO741': 'Colon',
#  'COLO800': 'Skin',
#  'COLO829': 'Blood',
#  'COV318': 'Ovary',
#  'COV504': 'Ovary',
#  'CW2': 'Colon',
#  'DAUDI': 'Blood',
#  'DB': 'Lymphoid',
#  'DEL': nan,
#  'DETROIT562': 'Head and Neck',
#  'DMS273': 'Lung',
#  'DOHH2': 'Lymphoid',
#  'DU145': 'Prostate',
#  'DV90': 'Lung',
#  'EFE184': 'Uterus',
#  'EFM19': 'Breast',
#  'EFO27': 'Ovary',
#  'EKVX': 'Lung',
#  'EPLC272H': 'Lung',
#  'ES2': 'Ovary',
#  'FADU': 'Head and Neck',
#  'FU97': 'Stomach',
#  'G361': 'Skin',
#  'G402': 'Kidney',
#  'GB1': 'Brain',
#  'GI1': 'Brain',
#  'GRANTA519': 'Lymphoid',
#  'HCC1143': 'Breast',
#  'HCC1187': 'Breast',
#  'HCC1419': 'Breast',
#  'HCC15': 'Lung',
#  'HCC1806': 'Breast',
#  'HCC1937': 'Breast',
#  'HCC1954': 'Breast',
#  'HCC2218': 'Breast',
#  'HCC38': 'Breast',
#  'HCC4006': 'Lung',
#  'HCC44': 'Lung',
#  'HCC78': 'Lung',
#  'HCC827': 'Lung',
#  'HCT116': 'Colon',
#  'HCT15': 'Colon',
#  'HDQP1': 'Breast',
#  'HEC151': 'Uterus',
#  'HEC1A': 'Uterus',
#  'HEC1B': 'Uterus',
#  'HEC251': 'Uterus',
#  'HEC265': 'Uterus',
#  'HEC59': 'Uterus',
#  'HEC6': 'Uterus',
#  'HEL': 'Blood',
#  'HEP3B217': 'Liver',
#  'HEPG2': 'Liver',
#  'HGC27': 'Stomach',
#  'HLF': 'Liver',
#  'HOP62': 'Lung',
#  'HOP92': 'Lung',
#  'HPAC': 'Pancreas',
#  'HPAFII': 'Pancreas',
#  'HS294T': 'Skin',
#  'HS578T': 'Breast',
#  'HS683': 'Brain',
#  'HS695T': 'Skin',
#  'HS746T': 'Stomach',
#  'HS766T': 'Pancreas',
#  'HS852T': 'Skin',
#  'HT': 'Lymphoid',
#  'HT1080': 'Bone',
#  'HT29': 'Colon',
#  'HT55': 'Colon',
#  'HUCCT1': 'Liver',
#  'HUH1': 'Liver',
#  'HUH7': 'Liver',
#  'HUPT3': 'Pancreas',
#  'HUPT4': 'Pancreas',
#  'IGR1': 'Skin',
#  'IGR37': 'Skin',
#  'IGR39': 'Skin',
#  'IGROV1': 'Ovary',
#  'IMR32': 'Brain',
#  'IPC298': 'Skin',
#  'JHH2': 'Liver',
#  'JHH4': 'Liver',
#  'JHH5': 'Liver',
#  'JHH7': 'Liver',
#  'K562': 'Blood',
#  'KALS1': 'Brain',
#  'KARPAS422': 'Blood',
#  'KARPAS620': 'Blood',
#  'KE39': 'Stomach',
#  'KE97': 'Stomach',
#  'KELLY': 'Brain',
#  'KG1': 'Blood',
#  'KHM1B': 'Blood',
#  'KLE': 'Uterus',
#  'KM12': 'Colon',
#  'KMM1': 'Blood',
#  'KMRC1': 'Kidney',
#  'KMS11': 'Blood',
#  'KMS12BM': 'Blood',
#  'KMS26': 'Blood',
#  'KMS34': 'Blood',
#  'KNS62': 'Lung',
#  'KNS81': 'Brain',
#  'KP3': 'Pancreas',
#  'KP4': 'Pancreas',
#  'KPNSI9S': 'Brain',
#  'KPNYN': 'Brain',
#  'KURAMOCHI': 'Ovary',
#  'KYSE140': 'Esophagus',
#  'KYSE150': 'Esophagus',
#  'KYSE180': 'Esophagus',
#  'KYSE270': 'Esophagus',
#  'KYSE30': 'Esophagus',
#  'KYSE410': 'Esophagus',
#  'KYSE450': 'Esophagus',
#  'KYSE510': 'Esophagus',
#  'KYSE520': 'Esophagus',
#  'KYSE70': 'Esophagus',
#  'L363': 'Blood',
#  'LCLC103H': 'Lung',
#  'LCLC97TM1': 'Lung',
#  'LN18': 'Brain',
#  'LN229': 'Brain',
#  'LNCAPCLONEFGC': 'Prostate',
#  'LOVO': 'Colon',
#  'LOXIMVI': 'Skin',
#  'LP1': 'Blood',
#  'LS1034': nan,
#  'LXF289': 'Lung',
#  'MALME3M': 'Skin',
#  'MC116': 'Lymphoid',
#  'MCAS': 'Ovary',
#  'MCF7': 'Breast',
#  'MDAMB157': 'Breast',
#  'MDAMB175VII': 'Breast',
#  'MDAMB231': 'Breast',
#  'MDAMB436': 'Breast',
#  'MDAMB453': 'Breast',
#  'MDAMB468': 'Breast',
#  'MELHO': 'Skin',
#  'MELJUSO': 'Skin',
#  'MEWO': 'Skin',
#  'MG63': 'Bone',
#  'MHHES1': 'Bone',
#  'MIAPACA2': 'Pancreas',
#  'MKN1': 'Stomach',
#  'MKN45': 'Stomach',
#  'MKN74': 'Stomach',
#  'MOLP8': 'Blood',
#  'MV411': 'Blood',
#  'NALM6': 'Blood',
#  'NB1': 'Brain',
#  'NCIH1155': 'Lung',
#  'NCIH1299': 'Lung',
#  'NCIH1339': 'Lung',
#  'NCIH1355': 'Lung',
#  'NCIH1437': 'Lung',
#  'NCIH1581': 'Lung',
#  'NCIH1648': 'Lung',
#  'NCIH1651': 'Lung',
#  'NCIH1666': 'Lung',
#  'NCIH1703': 'Lung',
#  'NCIH1838': 'Lung',
#  'NCIH1869': 'Lung',
#  'NCIH1944': 'Lung',
#  'NCIH2009': 'Lung',
#  'NCIH2023': 'Lung',
#  'NCIH2122': 'Lung',
#  'NCIH2170': 'Lung',
#  'NCIH2228': 'Lung',
#  'NCIH226': 'Lung',
#  'NCIH23': 'Lung',
#  'NCIH2347': 'Lung',
#  'NCIH2405': 'Lung',
#  'NCIH2452': 'Lung',
#  'NCIH28': 'Lung',
#  'NCIH358': 'Lung',
#  'NCIH441': 'Lung',
#  'NCIH446': 'Lung',
#  'NCIH460': 'Lung',
#  'NCIH520': 'Lung',
#  'NCIH522': 'Lung',
#  'NCIH647': 'Lung',
#  'NCIH650': 'Lung',
#  'NCIH661': 'Lung',
#  'NCIH716': nan,
#  'NCIH727': 'Lung',
#  'NCIH82': 'Lung',
#  'NCIH889': 'Lung',
#  'NCIN87': 'Stomach',
#  'NIHOVCAR3': 'Ovary',
#  'NOMO1': 'Blood',
#  'NUGC3': 'Stomach',
#  'NUGC4': 'Stomach',
#  'OAW42': 'Ovary',
#  'OCIAML2': 'Blood',
#  'OCIAML5': 'Blood',
#  'OCUM1': 'Stomach',
#  'OE19': 'Esophagus',
#  'OE21': 'Esophagus',
#  'OE33': 'Esophagus',
#  'ONCODG1': 'Ovary',
#  'ONS76': 'Brain',
#  'OPM2': 'Blood',
#  'OV90': 'Ovary',
#  'OVCAR4': 'Ovary',
#  'OVCAR8': 'Ovary',
#  'OVSAHO': 'Ovary',
#  'OVTOKO': 'Ovary',
#  'PA1': 'Ovary',
#  'PANC0203': 'Pancreas',
#  'PANC0327': 'Pancreas',
#  'PANC0403': 'Pancreas',
#  'PANC1005': 'Pancreas',
#  'PATU8902': 'Pancreas',
#  'PC3': 'Prostate',
#  'PK1': 'Pancreas',
#  'PK45H': 'Pancreas',
#  'PK59': 'Pancreas',
#  'PLCPRF5': 'Liver',
#  'PSN1': 'Pancreas',
#  'QGP1': 'Pancreas',
#  'RAJI': 'Blood',
#  'RCM1': 'Colon',
#  'RERFGC1B': 'Stomach',
#  'RERFLCMS': 'Lung',
#  'RKN': 'Ovary',
#  'RKO': 'Colon',
#  'RL': 'Lymphoid',
#  'RL952': 'Uterus',
#  'RMGI': 'Ovary',
#  'RPMI7951': 'Skin',
#  'RPMI8226': 'Blood',
#  'RT112': 'Urinary',
#  'RT4': 'Urinary',
#  'RVH421': 'Skin',
#  'S117': 'Thyroid',
#  'SCLC21H': 'Lung',
#  'SF268': 'Brain',
#  'SF539': 'Brain',
#  'SIHA': 'Cervix',
#  'SKBR3': 'Breast',
#  'SKCO1': 'Colon',
#  'SKHEP1': 'Liver',
#  'SKM1': 'Blood',
#  'SKMEL1': 'Skin',
#  'SKMEL24': 'Skin',
#  'SKMEL28': 'Skin',
#  'SKMEL3': 'Skin',
#  'SKMEL30': 'Skin',
#  'SKMES1': nan,
#  'SKNAS': 'Brain',
#  'SKNBE2': 'Brain',
#  'SKNDZ': 'Brain',
#  'SKNFI': 'Brain',
#  'SKNSH': 'Brain',
#  'SKOV3': 'Ovary',
#  'SNGM': 'Uterus',
#  'SNU16': 'Stomach',
#  'SNU182': 'Liver',
#  'SNU387': 'Liver',
#  'SNU398': 'Liver',
#  'SNU423': 'Liver',
#  'SNU449': 'Liver',
#  'SNU475': 'Liver',
#  'SNU5': 'Stomach',
#  'SNUC1': 'Colon',
#  'SU8686': 'Pancreas',
#  'SUDHL1': 'Lymphoid',
#  'SUDHL10': 'Lung',
#  'SUDHL4': 'Lymphoid',
#  'SUDHL8': 'Lymphoid',
#  'SUIT2': 'Pancreas',
#  'SW1463': 'Colon',
#  'SW1573': 'Lung',
#  'SW1990': 'Pancreas',
#  'SW403': 'Colon',
#  'SW48': 'Colon',
#  'SW480': 'Colon',
#  'SW620': 'Colon',
#  'SW626': 'Ovary',
#  'SW780': 'Urinary',
#  'SW837': nan,
#  'SW948': 'Colon',
#  'SW982': 'Breast',
#  'T47D': 'Breast',
#  'T84': 'Colon',
#  'T98G': 'Brain',
#  'TC71': 'Bone',
#  'TOV112D': 'Ovary',
#  'TOV21G': 'Ovary',
#  'TYKNU': 'Ovary',
#  'U266B1': 'Blood',
#  'U2OS': 'Bone',
#  'U87MG': 'Brain',
#  'U937': 'Blood',
#  'UACC62': 'Skin',
#  'UMUC3': 'Urinary',
#  'WM115': 'Skin',
#  'WM2664': 'Skin',
#  'YAPC': 'Pancreas'}

# %%
df_t = pd.DataFrame(tissue_dict,index = [0]).T
df_t = df_t.reset_index(inplace= False)
df_t.columns = ['Cell Line','Tissue']
df_t = df_t.sort_values(by = ['Tissue'],ascending = True)
df_t = df_t.reset_index(inplace= False,drop=True)

# %%
df_t.to_csv('cell_line_tissue.csv',sep = ',')
